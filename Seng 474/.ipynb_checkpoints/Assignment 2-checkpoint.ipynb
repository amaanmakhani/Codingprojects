# %%
import sklearn as sk
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import math

# %% [markdown]
# Load Data Set
# --

# %%
# Load train datasets
# This data set has already removed classes other than Class 5 and 7
f = open("fashion-mnist_train.csv")
trainData = np.loadtxt(f, delimiter= ",")
# Seperate target and feadtures
xTrain = trainData[:4000, 1:]
yTrain = trainData[:4000, 0]
# Pre-process data by rescaling inputs by 255
xTrain = [[number/255 for number in group] for group in xTrain]

# Load Test datasets
# This data set has already removed classes other than Class 5 and 7
f = open("fashion-mnist_test.csv")
testData = np.loadtxt(f, delimiter= ",")
# Seperate target and feadtures
xTest = testData[:, 1:]
yTest = testData[:, 0]
# Pre-process data by rescaling inputs by 255
xTest = [[number/255 for number in group] for group in xTest]

# %% [markdown]
# Misc Functions
# --

# %%
def plotGraph(a, fa, b = [], fb = [], name = 'untitiled', xvalrange = 100, yvalrange = 100 + 4, xAxisTitle = "", title = "", digits = 5, single = False, label = False):
    plt.clf()
    if not single:
        plt.plot(a, fa, linewidth=3.0, label='Training Data')
        plt.plot(b, fb, linewidth=3.0, label='Test Data')
    else:
        plt.plot(a, fa, linewidth=3.0, label='Dataset')
    ymin = min(fb) if not single else min(fa)
    xpos = fb.index(ymin) if not single else fa.index(ymin)
    xmin = b[xpos]  if not single else a[xpos] 
    plt.annotate('Minimum \n(' + str(xmin) + ', ' + str(ymin)[0:digits] + ')', xy=(xmin, ymin), xytext=(xmin, ymin + 10), arrowprops=dict(facecolor='black', shrink=0.05))
    if label:
        ymin = min(fa)
        xpos = fa.index(ymin)
        xmin = a[xpos] 
        plt.annotate('Minimum \n(' + str(xmin) + ', ' + str(ymin)[0:digits] + ')', xy=(xmin, ymin), xytext=(xmin, ymin - 5), arrowprops=dict(facecolor='blue', shrink=0.05))
    plt.xlabel(xAxisTitle)
    plt.ylabel('Error (%)')
    plt.xlim(0, xvalrange)
    plt.ylim(0, yvalrange)
    plt.title(title + ' vs. Error')
    plt.legend(loc = 'lower right')
    plt.savefig(name  + '.png')

# %%
def stats(pred, test, debug = True):
    if debug:
        print("\n-----------------------------------Metrics-----------------------------------")
        print('Mean Absolute Error:', metrics.mean_absolute_error(test, pred))
        print('           Accuracy:',accuracy_score(test, pred))
        print("\n-----------------------------------Report------------------------------------")
        print(classification_report(test,pred))
    return metrics.mean_absolute_error(test, pred)

# %% [markdown]
# Logistic Regression
# --

# %%
def executeLogisticRegression(xTrain = [], yTrain = [], xTest = [], yTest = [], c = 1.0, pen = 'l2', train = True, test = True):
    clf = LogisticRegression(C = 1/c, penalty = pen)
    # Penalty: Used to specify the norm used in the penalization.
    # C: Inverse of regularization strength; smaller values specify stronger regularization.
    result = []
    clf = clf.fit(xTrain, yTrain)
    if train:
        result.append(stats(clf.predict(xTrain), yTrain))
    if test:
        result.append(stats(clf.predict(xTest), yTest))
    return result

# %% [markdown]
# SVM
# --

# %%
def executeSVM(xTrain = [], yTrain = [], xTest = [], yTest = [], c = 1.0, k = 'rbf', d = 3, g = 'scale', coef = 0.0, train = True, test = True):
    clf = SVC(C = 1/c, kernel = k, degree = 3, gamma = g, coef0 = coef )
    # C, Regularization parameter.The strength of the regularization is inversely proportional to C. 
        # Must be strictly positive. The penalty is a squared l2 penalty.
    # kernel{‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’} , specifies the kernel type to be used in the algorithm.
    # Degree of the polynomial kernel function (‘poly’). Ignored by all other kernels.
    # Gamma{‘scale’, ‘auto’} or float, kernel coefficient for ‘rbf’, ‘poly’ and ‘sigmoid’.
    # coef0, Independent term in kernel function. It is only significant in ‘poly’ and ‘sigmoid’.
    result = []
    clf = clf.fit(xTrain, yTrain)    
    if train:
        result.append(stats(clf.predict(xTrain), yTrain))
    if test:
        result.append(stats(clf.predict(xTest), yTest))
    return result

# %% [markdown]
# K-fold cross-validation
# --

# %%
def executeKfold(X, Y, k):
    result = []
    kSize = int(len(X)/k)
    i = 0
    while i + kSize <= len(X):
        result.append(X[i: i + kSize])
        result.append(Y[i: i + kSize])
        i += kSize
    return result

# %%
def createSets(data, index):
    result = []
    for i in range(0, int(len(data)/2)):
        if i != index:
            if len(result) == 0:
                result.append(list(data[2*i]))
                result.append(list(data[2*i + 1]))
            else:
                result[0].extend(list(data[2*i]))
                result[1].extend(list(data[2*i + 1]))
    result.append(data[2 * index])
    result.append(data[2 * index + 1])
    return result

# %% [markdown]
# Task One
# --

# %%
x = []
fa = []
fb = []
for i in range(0, 11):
    error = executeLogisticRegression(xTrain, yTrain, xTest, yTest, c = 0.001*(3.5**i))
    x.append(i)
    fa.append(error[0] * 100)
    fb.append(error[1] * 100)
plotGraph(x, fa, x, fb, "TaskOne", xvalrange = 10, yvalrange = 18, xAxisTitle = "Regularization Strength (0.001*3.5$^x$)", title = "Regularization Strength", digits = 4)
# Out:
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.0075
#            Accuracy: 0.99625
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       1.00      1.00      1.00      1968
#          7.0       1.00      1.00      1.00      2032
#
#     accuracy                           1.00      4000
#    macro avg       1.00      1.00      1.00      4000
# weighted avg       1.00      1.00      1.00      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.132
#            Accuracy: 0.934
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.94      0.93      0.93      1000
#          7.0       0.93      0.94      0.93      1000
#
#     accuracy                           0.93      2000
#    macro avg       0.93      0.93      0.93      2000
# weighted avg       0.93      0.93      0.93      2000
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.01
#            Accuracy: 0.995
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       1.00      0.99      0.99      1968
#          7.0       0.99      1.00      1.00      2032
#
#     accuracy                           0.99      4000
#    macro avg       1.00      0.99      0.99      4000
# weighted avg       1.00      0.99      0.99      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.127
#            Accuracy: 0.9365
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.94      0.93      0.94      1000
#          7.0       0.93      0.94      0.94      1000
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.008
#            Accuracy: 0.996
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       1.00      0.99      1.00      1968
#          7.0       1.00      1.00      1.00      2032
#
#     accuracy                           1.00      4000
#    macro avg       1.00      1.00      1.00      4000
# weighted avg       1.00      1.00      1.00      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.127
#            Accuracy: 0.9365
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.94      0.93      0.94      1000
#          7.0       0.93      0.94      0.94      1000
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.017
#            Accuracy: 0.9915
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.99      0.99      0.99      1968
#          7.0       0.99      0.99      0.99      2032
#
#     accuracy                           0.99      4000
#    macro avg       0.99      0.99      0.99      4000
# weighted avg       0.99      0.99      0.99      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.121
#            Accuracy: 0.9395
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.95      0.93      0.94      1000
#          7.0       0.93      0.95      0.94      1000
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.0225
#            Accuracy: 0.98875
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.99      0.99      0.99      1968
#          7.0       0.99      0.99      0.99      2032
#
#     accuracy                           0.99      4000
#    macro avg       0.99      0.99      0.99      4000
# weighted avg       0.99      0.99      0.99      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.119
#            Accuracy: 0.9405
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.95      0.93      0.94      1000
#          7.0       0.93      0.95      0.94      1000
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.035
#            Accuracy: 0.9825
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.98      0.98      0.98      1968
#          7.0       0.98      0.98      0.98      2032
#
#     accuracy                           0.98      4000
#    macro avg       0.98      0.98      0.98      4000
# weighted avg       0.98      0.98      0.98      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.114
#            Accuracy: 0.943
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.95      0.94      0.94      1000
#          7.0       0.94      0.95      0.94      1000
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.0455
#            Accuracy: 0.97725
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.98      0.97      0.98      1968
#          7.0       0.98      0.98      0.98      2032
#
#     accuracy                           0.98      4000
#    macro avg       0.98      0.98      0.98      4000
# weighted avg       0.98      0.98      0.98      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.106
#            Accuracy: 0.947
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.95      0.94      0.95      1000
#          7.0       0.94      0.95      0.95      1000
#
#     accuracy                           0.95      2000
#    macro avg       0.95      0.95      0.95      2000
# weighted avg       0.95      0.95      0.95      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.066
#            Accuracy: 0.967
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.97      0.96      0.97      1968
#          7.0       0.96      0.97      0.97      2032
#
#     accuracy                           0.97      4000
#    macro avg       0.97      0.97      0.97      4000
# weighted avg       0.97      0.97      0.97      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.102
#            Accuracy: 0.949
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.95      0.94      0.95      1000
#          7.0       0.95      0.95      0.95      1000
#
#     accuracy                           0.95      2000
#    macro avg       0.95      0.95      0.95      2000
# weighted avg       0.95      0.95      0.95      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.0895
#            Accuracy: 0.95525
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.96      0.95      0.95      1968
#          7.0       0.95      0.96      0.96      2032
#
#     accuracy                           0.96      4000
#    macro avg       0.96      0.96      0.96      4000
# weighted avg       0.96      0.96      0.96      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.113
#            Accuracy: 0.9435
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.95      0.94      0.94      1000
#          7.0       0.94      0.95      0.94      1000
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.1305
#            Accuracy: 0.93475
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.93      0.93      0.93      1968
#          7.0       0.93      0.94      0.94      2032
#
#     accuracy                           0.93      4000
#    macro avg       0.93      0.93      0.93      4000
# weighted avg       0.93      0.93      0.93      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.126
#            Accuracy: 0.937
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.94      0.94      0.94      1000
#          7.0       0.94      0.94      0.94      1000
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.171
#            Accuracy: 0.9145
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.91      0.91      0.91      1968
#          7.0       0.92      0.92      0.92      2032
#
#     accuracy                           0.91      4000
#    macro avg       0.91      0.91      0.91      4000
# weighted avg       0.91      0.91      0.91      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.175
#            Accuracy: 0.9125
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.92      0.91      0.91      1000
#          7.0       0.91      0.92      0.91      1000
#
#     accuracy                           0.91      2000
#    macro avg       0.91      0.91      0.91      2000
# weighted avg       0.91      0.91      0.91      2000

# %% [markdown]
# Task Two
# --

# %%
x = []
fa = []
fb = []
for i in range(0, 11):
    error = executeSVM(xTrain, yTrain, xTest, yTest, k = 'linear', c =  0.0045*(3.2**i))
    x.append(i)
    fa.append(error[0] * 100)
    fb.append(error[1] * 100)
plotGraph(x, fa, x, fb, "TaskTwo", xvalrange = 10, yvalrange = 18, xAxisTitle = "Regularization Strength (0.004*3.2$^x$)", title = "Regularization Strength", digits = 4)
# Out:
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.0
#            Accuracy: 1.0
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       1.00      1.00      1.00      1968
#          7.0       1.00      1.00      1.00      2032
#
#     accuracy                           1.00      4000
#    macro avg       1.00      1.00      1.00      4000
# weighted avg       1.00      1.00      1.00      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.148
#            Accuracy: 0.926
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.93      0.92      0.93      1000
#          7.0       0.92      0.94      0.93      1000
#
#     accuracy                           0.93      2000
#    macro avg       0.93      0.93      0.93      2000
# weighted avg       0.93      0.93      0.93      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.001
#            Accuracy: 0.9995
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       1.00      1.00      1.00      1968
#          7.0       1.00      1.00      1.00      2032
#
#     accuracy                           1.00      4000
#    macro avg       1.00      1.00      1.00      4000
# weighted avg       1.00      1.00      1.00      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.144
#            Accuracy: 0.928
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.93      0.92      0.93      1000
#          7.0       0.92      0.94      0.93      1000
#
#     accuracy                           0.93      2000
#    macro avg       0.93      0.93      0.93      2000
# weighted avg       0.93      0.93      0.93      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.004
#            Accuracy: 0.998
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       1.00      1.00      1.00      1968
#          7.0       1.00      1.00      1.00      2032
#
#     accuracy                           1.00      4000
#    macro avg       1.00      1.00      1.00      4000
# weighted avg       1.00      1.00      1.00      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.143
#            Accuracy: 0.9285
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.93      0.92      0.93      1000
#          7.0       0.92      0.93      0.93      1000
#
#     accuracy                           0.93      2000
#    macro avg       0.93      0.93      0.93      2000
# weighted avg       0.93      0.93      0.93      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.013
#            Accuracy: 0.9935
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.99      0.99      0.99      1968
#          7.0       0.99      1.00      0.99      2032
#
#     accuracy                           0.99      4000
#    macro avg       0.99      0.99      0.99      4000
# weighted avg       0.99      0.99      0.99      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.126
#            Accuracy: 0.937
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.95      0.93      0.94      1000
#          7.0       0.93      0.95      0.94      1000
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.024
#            Accuracy: 0.988
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.99      0.99      0.99      1968
#          7.0       0.99      0.99      0.99      2032
#
#     accuracy                           0.99      4000
#    macro avg       0.99      0.99      0.99      4000
# weighted avg       0.99      0.99      0.99      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.127
#            Accuracy: 0.9365
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.94      0.93      0.94      1000
#          7.0       0.93      0.95      0.94      1000
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.0305
#            Accuracy: 0.98475
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.99      0.98      0.98      1968
#          7.0       0.98      0.99      0.99      2032
#
#     accuracy                           0.98      4000
#    macro avg       0.98      0.98      0.98      4000
# weighted avg       0.98      0.98      0.98      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.124
#            Accuracy: 0.938
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.95      0.93      0.94      1000
#          7.0       0.93      0.95      0.94      1000
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.0455
#            Accuracy: 0.97725
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.98      0.97      0.98      1968
#          7.0       0.97      0.98      0.98      2032
#
#     accuracy                           0.98      4000
#    macro avg       0.98      0.98      0.98      4000
# weighted avg       0.98      0.98      0.98      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.112
#            Accuracy: 0.944
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.95      0.93      0.94      1000
#          7.0       0.94      0.95      0.94      1000
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.0545
#            Accuracy: 0.97275
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.98      0.96      0.97      1968
#          7.0       0.97      0.98      0.97      2032
#
#     accuracy                           0.97      4000
#    macro avg       0.97      0.97      0.97      4000
# weighted avg       0.97      0.97      0.97      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.1
#            Accuracy: 0.95
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.96      0.94      0.95      1000
#          7.0       0.94      0.96      0.95      1000
#
#     accuracy                           0.95      2000
#    macro avg       0.95      0.95      0.95      2000
# weighted avg       0.95      0.95      0.95      2000
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.075
#            Accuracy: 0.9625
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.97      0.95      0.96      1968
#          7.0       0.95      0.97      0.96      2032
#
#     accuracy                           0.96      4000
#    macro avg       0.96      0.96      0.96      4000
# weighted avg       0.96      0.96      0.96      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.104
#            Accuracy: 0.948
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.96      0.94      0.95      1000
#          7.0       0.94      0.96      0.95      1000
#
#     accuracy                           0.95      2000
#    macro avg       0.95      0.95      0.95      2000
# weighted avg       0.95      0.95      0.95      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.0995
#            Accuracy: 0.95025
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.96      0.94      0.95      1968
#          7.0       0.94      0.96      0.95      2032
#
#     accuracy                           0.95      4000
#    macro avg       0.95      0.95      0.95      4000
# weighted avg       0.95      0.95      0.95      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.112
#            Accuracy: 0.944
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.95      0.94      0.94      1000
#          7.0       0.94      0.95      0.94      1000
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.14
#            Accuracy: 0.93
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.93      0.93      0.93      1968
#          7.0       0.93      0.93      0.93      2032
#
#     accuracy                           0.93      4000
#    macro avg       0.93      0.93      0.93      4000
# weighted avg       0.93      0.93      0.93      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.136
#            Accuracy: 0.932
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.93      0.93      0.93      1000
#          7.0       0.93      0.93      0.93      1000
#
#     accuracy                           0.93      2000
#    macro avg       0.93      0.93      0.93      2000
# weighted avg       0.93      0.93      0.93      2000

# %% [markdown]
# Task Three
# --

# %%
x = []
yLR = []
ySVM = []
optimalRegularizationLG = 0
optimalRegularizationSVM = 0
minValidationError = np.inf
fold = 8

Validation = executeKfold(xTrain, yTrain, fold)
for i in range(0, 11):
    temp = 0
    for k in range(0, fold):
        regularizationStrength = 0.001*(3.5**i)
        kFoldData = createSets(Validation, k)
        error = executeLogisticRegression(kFoldData[0], kFoldData[1], kFoldData[2], kFoldData[3], c = regularizationStrength)
        temp += error[1]
    temp = temp/fold
    if temp < minValidationError:
        minValidationError = temp
        optimalRegularizationLG = regularizationStrength
    x.append(i)
    yLR.append(temp * 100)

minValidationError = np.inf
Validation = executeKfold(xTrain, yTrain, fold)
for i in range(0, 11):
    temp = 0
    for k in range(0, fold):
        regularizationStrength = 0.0045*(3.2**i)
        kFoldData = createSets(Validation, k)
        error = executeSVM(kFoldData[0], kFoldData[1], kFoldData[2], kFoldData[3], k = 'linear', c = regularizationStrength)
        temp += error[1]
    temp = temp/fold
    if temp < minValidationError:
        minValidationError = temp
        optimalRegularizationSVM = regularizationStrength
    ySVM.append(temp * 100)
    
plotGraph(x, ySVM, x, yLR, "TaskThree", xvalrange = 10, yvalrange = 18, xAxisTitle = "Regularization Strength Exponent", title = "Regularization Strength", digits = 4, label = True)
result = executeLogisticRegression(xTrain, yTrain, xTest, yTest, c = optimalRegularizationSVM, train = False)
print("Optimized Logistic Regression error = " + str(result[0]))
result = executeSVM(xTrain, yTrain, xTest, yTest, c = optimalRegularizationSVM, k = 'linear', train = False)
print("Optimized SVM error = " + str(result[0]))
# Out:
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.92      0.93      0.93      1717
#          7.0       0.93      0.93      0.93      1783
#
#     accuracy                           0.93      3500
#    macro avg       0.93      0.93      0.93      3500
# weighted avg       0.93      0.93      0.93      3500
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.156
#            Accuracy: 0.922
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.93      0.92      0.92       251
#          7.0       0.92      0.93      0.92       249
#
#     accuracy                           0.92       500
#    macro avg       0.92      0.92      0.92       500
# weighted avg       0.92      0.92      0.92       500
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.105
#            Accuracy: 0.9475
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.95      0.94      0.95      1000
#          7.0       0.94      0.95      0.95      1000
#
#     accuracy                           0.95      2000
#    macro avg       0.95      0.95      0.95      2000
# weighted avg       0.95      0.95      0.95      2000
#
# Optimized Logistic Regression error = 0.105
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.112
#            Accuracy: 0.944
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.95      0.93      0.94      1000
#          7.0       0.94      0.95      0.94      1000
#
#     accuracy                           0.94      2000
#    macro avg       0.94      0.94      0.94      2000
# weighted avg       0.94      0.94      0.94      2000
#
# Optimized SVM error = 0.112

# %% [markdown]
# Task Four
# --

# %%
fa = []
fb = []
gammaValues = [0.0001, 0.01, 0.05, 0.1, 0.2, 0.3]
fold = 8
optmizedValues = {}
optimalRegularizationSVM = 0

Validation = executeKfold(xTrain, yTrain, fold)
for gamma in gammaValues:
    minValidationError = np.inf
    currentValidationError = np.inf
    for i in range(0, 11):
        temp = 0
        regularizationStrength =  0.0045*(3.2**i)
        for k in range(0, fold):
            kFoldData = createSets(Validation, k)
            error = executeSVM(kFoldData[0], kFoldData[1], kFoldData[2], kFoldData[3], c = regularizationStrength, g = gamma)
            temp += error[1]
        temp = temp/fold
        if temp < minValidationError:
            minValidationError = temp
            optimalRegularizationSVM = regularizationStrength
        if minValidationError < currentValidationError:
            optmizedValues[gamma] = optimalRegularizationSVM
            currentValidationError = minValidationError
    
for gamma, regularization in optmizedValues.items():
    error = executeSVM(xTrain, yTrain, xTest, yTest, g = gamma, c = regularization)
    fa.append(error[0] * 100)
    fb.append(error[1] * 100)
print(optmizedValues)
plotGraph(gammaValues, fa, gammaValues, fb, name = "TaskFour", xvalrange = max(gammaValues), yvalrange =  max(max(fa), max(fb)) + 6, xAxisTitle = "γ", title = "Gamma", digits = 4)
# Out:
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.05771428571428571
#            Accuracy: 0.9711428571428572
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.98      0.96      0.97      1734
#          7.0       0.96      0.98      0.97      1766
#
#     accuracy                           0.97      3500
#    macro avg       0.97      0.97      0.97      3500
# weighted avg       0.97      0.97      0.97      3500
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.084
#            Accuracy: 0.958
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.96      0.95      0.96       234
#          7.0       0.96      0.96      0.96       266
#
#     accuracy                           0.96       500
#    macro avg       0.96      0.96      0.96       500
# weighted avg       0.96      0.96      0.96       500
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.05828571428571429
#            Accuracy: 0.9708571428571429
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.98      0.96      0.97      1717
#          7.0       0.97      0.98      0.97      1783
#
#     accuracy                           0.97      3500
#    macro avg       0.97      0.97      0.97      3500
# weighted avg       0.97      0.97      0.97      3500
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.072
#            Accuracy: 0.964
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.98      0.94      0.96       251
#          7.0       0.95      0.98      0.96       249
#
#     accuracy                           0.96       500
#    macro avg       0.96      0.96      0.96       500
# weighted avg       0.96      0.96      0.96       500
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.05828571428571429
#            Accuracy: 0.9708571428571429
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.98      0.96      0.97      1711
#          7.0       0.97      0.98      0.97      1789
#
#     accuracy                           0.97      3500
#    macro avg       0.97      0.97      0.97      3500
# weighted avg       0.97      0.97      0.97      3500
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.1
#            Accuracy: 0.95
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.97      0.93      0.95       257
#          7.0       0.93      0.97      0.95       243
#
#     accuracy                           0.95       500
#    macro avg       0.95      0.95      0.95       500
# weighted avg       0.95      0.95      0.95       500
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.05885714285714286
#            Accuracy: 0.9705714285714285
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.98      0.96      0.97      1731
#          7.0       0.97      0.98      0.97      1769
#
#     accuracy                           0.97      3500
#    macro avg       0.97      0.97      0.97      3500
# weighted avg       0.97      0.97      0.97      3500
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.092
#            Accuracy: 0.954
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.95      0.96      0.95       237
#          7.0       0.96      0.95      0.96       263
#
#     accuracy                           0.95       500
#    macro avg       0.95      0.95      0.95       500
# weighted avg       0.95      0.95      0.95       500
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.06285714285714286
#            Accuracy: 0.9685714285714285
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.97      0.96      0.97      1721
#          7.0       0.96      0.97      0.97      1779
#
#     accuracy                           0.97      3500
#    macro avg       0.97      0.97      0.97      3500
# weighted avg       0.97      0.97      0.97      3500
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.1
#            Accuracy: 0.95
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.97      0.93      0.95       247
#          7.0       0.94      0.97      0.95       253
#
#     accuracy                           0.95       500
#    macro avg       0.95      0.95      0.95       500
# weighted avg       0.95      0.95      0.95       500
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.061714285714285715
#            Accuracy: 0.9691428571428572
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.98      0.96      0.97      1734
#          7.0       0.96      0.98      0.97      1766
#
#     accuracy                           0.97      3500
#    macro avg       0.97      0.97      0.97      3500
# weighted avg       0.97      0.97      0.97      3500
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.064
#            Accuracy: 0.968
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.97      0
500
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.9908571428571429
#            Accuracy: 0.5045714285714286
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.00      0.00      0.00      1734
#          7.0       0.50      1.00      0.67      1766
#
#     accuracy                           0.50      3500
#    macro avg       0.25      0.50      0.34      3500
# weighted avg       0.25      0.50      0.34      3500
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.936
#            Accuracy: 0.532
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.00      0.00      0.00       234
#          7.0       0.53      1.00      0.69       266
#
#     accuracy                           0.53       500
#    macro avg       0.27      0.50      0.35       500
# weighted avg       0.28      0.53      0.37       500
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.9777142857142858
#            Accuracy: 0.5111428571428571
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.00      0.00      0.00      1711
#          7.0       0.51      1.00      0.68      1789
#
#     accuracy                           0.51      3500
#    macro avg       0.26      0.50      0.34      3500
# weighted avg       0.26      0.51      0.35      3500
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 1.028
#            Accuracy: 0.486
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.00      0.00      0.00       257
#          7.0       0.49      1.00      0.65       243
#
#     accuracy                           0.49       500
#    macro avg       0.24      0.50      0.33       500
# weighted avg       0.24      0.49      0.32       500
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.9811428571428571
#            Accuracy: 0.5094285714285715
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.00      0.00      0.00      1717
#          7.0       0.51      1.00      0.67      1783
#
#     accuracy                           0.51      3500
#    macro avg       0.25      0.50      0.34      3500
# weighted avg       0.26      0.51      0.34      3500
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 1.004
#            Accuracy: 0.498
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.00      0.00      0.00       251
#          7.0       0.50      1.00      0.66       249
#
#     accuracy                           0.50       500
#    macro avg       0.25      0.50      0.33       500
# weighted avg       0.25      0.50      0.33       500
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.0605
#            Accuracy: 0.96975
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.97      0.96      0.97      1968
#          7.0       0.97      0.97      0.97      2032
#
#     accuracy                           0.97      4000
#    macro avg       0.97      0.97      0.97      4000
# weighted avg       0.97      0.97      0.97      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.099
#            Accuracy: 0.9505
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.96      0.94      0.95      1000
#          7.0       0.94      0.96      0.95      1000
#
#     accuracy                           0.95      2000
#    macro avg       0.95      0.95      0.95      2000
# weighted avg       0.95      0.95      0.95      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.0
#            Accuracy: 1.0
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       1.00      1.00      1.00      1968
#          7.0       1.00      1.00      1.00      2032
#
#     accuracy                           1.00      4000
#    macro avg       1.00      1.00      1.00      4000
# weighted avg       1.00      1.00      1.00      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.058
#            Accuracy: 0.971
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.98      0.96      0.97      1000
#          7.0       0.96      0.98      0.97      1000
#
#     accuracy                           0.97      2000
#    macro avg       0.97      0.97      0.97      2000
# weighted avg       0.97      0.97      0.97      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.0
#            Accuracy: 1.0
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       1.00      1.00      1.00      1968
#          7.0       1.00      1.00      1.00      2032
#
#     accuracy                           1.00      4000
#    macro avg       1.00      1.00      1.00      4000
# weighted avg       1.00      1.00      1.00      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.057
#            Accuracy: 0.9715
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.97      0.97      0.97      1000
#          7.0       0.97      0.97      0.97      1000
#
#     accuracy                           0.97      2000
#    macro avg       0.97      0.97      0.97      2000
# weighted avg       0.97      0.97      0.97      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.0
#            Accuracy: 1.0
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       1.00      1.00      1.00      1968
#          7.0       1.00      1.00      1.00      2032
#
#     accuracy                           1.00      4000
#    macro avg       1.00      1.00      1.00      4000
# weighted avg       1.00      1.00      1.00      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.084
#            Accuracy: 0.958
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.95      0.97      0.96      1000
#          7.0       0.97      0.95      0.96      1000
#
#     accuracy                           0.96      2000
#    macro avg       0.96      0.96      0.96      2000
# weighted avg       0.96      0.96      0.96      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.0
#            Accuracy: 1.0
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       1.00      1.00      1.00      1968
#          7.0       1.00      1.00      1.00      2032
#
#     accuracy                           1.00      4000
#    macro avg       1.00      1.00      1.00      4000
# weighted avg       1.00      1.00      1.00      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.224
#            Accuracy: 0.888
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.83      0.98      0.90      1000
#          7.0       0.98      0.79      0.88      1000
#
#     accuracy                           0.89      2000
#    macro avg       0.90      0.89      0.89      2000
# weighted avg       0.90      0.89      0.89      2000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.0
#            Accuracy: 1.0
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       1.00      1.00      1.00      1968
#          7.0       1.00      1.00      1.00      2032
#
#     accuracy                           1.00      4000
#    macro avg       1.00      1.00      1.00      4000
# weighted avg       1.00      1.00      1.00      4000
#
#
# -----------------------------------Metrics-----------------------------------
# Mean Absolute Error: 0.376
#            Accuracy: 0.812
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#          5.0       0.73      0.99      0.84      1000
#          7.0       0.98      0.63      0.77      1000
#
#     accuracy                           0.81      2000
#    macro avg       0.86      0.81      0.81      2000
# weighted avg       0.86      0.81      0.81      2000
#
# {0.0001: 0.0045, 0.01: 0.04608, 0.05: 0.0045, 0.1: 0.47185920000000003, 0.2: 0.0045, 0.3: 0.0045}
