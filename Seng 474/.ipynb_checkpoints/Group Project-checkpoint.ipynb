# %%
import sklearn as sk
from matplotlib import pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.neural_network import MLPClassifier

# %%
import numpy as np
import pandas as pd
import random
def apply(dataRow):
    ret = list(dataRow[0:11])
    if random.choice([True, False]):
        ret = list(dataRow[0:2])
        ret.extend(list(dataRow[6:10]))
        ret.extend(list(dataRow[2:6]))
        ret.append('0')
    return ret

def addStats(dataRow, playerData):
    ret = list(dataRow[0:2])
    ret.extend(list(playerData[float(dataRow[2])]))
    ret.extend(list(dataRow[3:6]))
    ret.extend(list(playerData[float(dataRow[6])]))
    ret.extend(list(dataRow[7:]))
    return ret

# %%
# Load data
fGameData = pd.read_csv("ATP_data_cleaned.csv", delimiter=',')
gameData = np.array([list(row) for row in fGameData.values])
# Seperate features and target columns
gameData =  np.array([apply(item) for item in gameData])
X = gameData[:, 0:10]
Y = gameData[:, 10]
# Add in player data
fGameData = pd.read_csv("ATP_player_data.csv", delimiter=',')
playerData = np.array([list(row) for row in fGameData.values])
playerData = dict((float(row[1]),list(row[2:])) for row in playerData)
X = np.array([addStats(item, playerData) for item in X], dtype='float64')
X = X.astype(np.float)

# %% [markdown]
# Misc functions
# --

# %%
def stats(pred, test):
    print("\n-----------------------------------Report------------------------------------")
    print(classification_report(test,pred))
    print('Accuracy: ',accuracy_score(test, pred))
    print("\n")
    return accuracy_score(test, pred)

# %%
def findBestParams(X, Y, pIndex):
    parameters = {'solver': ['lbfgs','sgd'], 'max_iter': np.arange(start=1, stop=800, step=5),'hidden_layer_sizes': np.arange(10, 200, 10), 'learning_rate': ['constant', 'invscaling', 'adaptive']} 
    clf = GridSearchCV(MLPClassifier(), parameters, n_jobs=-1)
    clf.fit(X,Y)
    print(clf.best_params_)
    print(clf.best_score_)

# %% [markdown]
# Plot Graph
# --

# %%
def plotGraph(a, fa, b, fb, name, xvalrange = 100, xAxisTitle = 'Test Size (%)', title = "Test Size", digits = 5):
    plt.clf()
    plt.plot(a, fa, linewidth=3.0, label='Training Data')
    plt.plot(b, fb, linewidth=3.0, label='Test Data')
    ymax = max(fb)
    plt.xlabel(xAxisTitle)
    plt.ylabel('Error (%)')
    plt.xlim(0, xvalrange)
    plt.ylim(0, ymax + 10)
    plt.title(title + ' vs. Error')
    plt.legend(loc = 'lower right')
    plt.savefig(name  + '.png')

# %% [markdown]
# Build Artificial Neural Network
# --

# %%
def executeNeuralNetwork(X, Y, testSize = 0.2, rand = 0, layers = (100,), solverType = 'adam', a = 0.0001, learningRate = 'constant', learningRateVal = 0.001, iterations = 200, earlyStopping = False, validationSet = 0.1, act = 'relu'):
    classifier =  MLPClassifier(hidden_layer_sizes = layers , solver = solverType, alpha = a, learning_rate = learningRate, learning_rate_init = learningRateVal , max_iter = iterations, random_state = rand, early_stopping = earlyStopping, validation_fraction = validationSet, activation = act)
    # hidden_layer_sizes: The ith element represents the number of neurons in the ith hidden layer.
    # solver: ‘lbfgs’ is an optimizer in the family of quasi-Newton methods, and ‘sgd’ refers to stochastic gradient descent.
    # alpha: L2 penalty (regularization term) parameter.
    # learning_rate: Learning rate schedule for weight updates, and only used when solver='sgd'.
    # learning_rate_init: The initial learning rate used. It controls the step-size in updating the weights. Only used when solver=’sgd’ or ‘adam’.
    # max_iter: Maximum number of iterations. For sgd this determines the number of epochs (how many times each data point will be used), not the number of gradient steps.
    # random_state: Determines random number generation for weights and bias initialization.
    # early_stopping: Whether to use early stopping to terminate training when validation score is not improving.
    #                 If set to true, it will automatically set aside 10% of training data as validation and terminate training when validation score is not improving.
    #                 Only effective when solver=’sgd’ or ‘adam’.
    # validation_fraction: The proportion of training data to set aside as validation set for early stopping. Must be between 0 and 1. Only used if early_stopping is True.
    result = []
    print("Parameters:")
    print(classifier.get_params())
    xTrain, xTest, yTrain, yTest = train_test_split(X, Y, test_size = testSize, random_state = rand)
    clf = classifier.fit(xTrain, yTrain)    
    result.append(1 - stats(clf.predict(xTrain), yTrain))
    result.append(1 - stats(clf.predict(xTest), yTest))
    return [result, clf]

# %% [markdown]
# Main program -- Neural Networks
# --

# %%
 executeNeuralNetwork(X, Y, solverType = 'sgd')
# Out:
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'sgd', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.75      0.68     32768
#          1.0       0.69      0.56      0.62     32838
#
#     accuracy                           0.65     65606
#    macro avg       0.66      0.65      0.65     65606
# weighted avg       0.66      0.65      0.65     65606
#
# Accuracy:  0.654315154101759
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.75      0.68      8162
#          1.0       0.69      0.55      0.61      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.64     16402
#
# Accuracy:  0.6481526643092306
# [[0.345684845898241, 0.3518473356907694],
#  MLPClassifier(random_state=0, solver='sgd')]

# %%
 executeNeuralNetwork(X, Y)
# Out:
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
# [[0.42772002560741396, 0.4286062675283502], MLPClassifier(random_state=0)]

# %%
 executeNeuralNetwork(X, Y, solverType = 'sgd', act = 'tanh')
# Out:
# Parameters:
# {'activation': 'tanh', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'sgd', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.71      0.67     32768
#          1.0       0.67      0.58      0.62     32838
#
#     accuracy                           0.64     65606
#    macro avg       0.65      0.64      0.64     65606
# weighted avg       0.65      0.64      0.64     65606
#
# Accuracy:  0.6444532512270219
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.66      8162
#          1.0       0.66      0.57      0.61      8240
#
#     accuracy                           0.64     16402
#    macro avg       0.64      0.64      0.64     16402
# weighted avg       0.64      0.64      0.64     16402
#
# Accuracy:  0.6391293744665285
# [[0.3555467487729781, 0.3608706255334715],
#  MLPClassifier(activation='tanh', random_state=0, solver='sgd')]

# %%
 executeNeuralNetwork(X, Y, act = 'tanh')
# Out:
# Parameters:
# {'activation': 'tanh', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.66      0.62      0.64     32768
#          1.0       0.64      0.69      0.67     32838
#
#     accuracy                           0.65     65606
#    macro avg       0.65      0.65      0.65     65606
# weighted avg       0.65      0.65      0.65     65606
#
# Accuracy:  0.6539036063774655
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.66      0.61      0.63      8162
#          1.0       0.64      0.69      0.66      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.6491281551030362
# [[0.3460963936225345, 0.35087184489696377],
#  MLPClassifier(activation='tanh', random_state=0)]

# %%
 executeNeuralNetwork(X, Y, act = 'logistic', solverType = 'sgd')
# Out:
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'sgd', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.66      0.65      0.65     32768
#          1.0       0.65      0.66      0.66     32838
#
#     accuracy                           0.65     65606
#    macro avg       0.65      0.65      0.65     65606
# weighted avg       0.65      0.65      0.65     65606
#
# Accuracy:  0.6542694265768375
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.64      0.65      8162
#          1.0       0.65      0.66      0.66      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.6517497866113888
# [[0.3457305734231625, 0.3482502133886112],
#  MLPClassifier(activation='logistic', random_state=0, solver='sgd')]

# %%
 executeNeuralNetwork(X, Y, act = 'logistic')
# Out:
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65     32768
#          1.0       0.65      0.65      0.65     32838
#
#     accuracy                           0.65     65606
#    macro avg       0.65      0.65      0.65     65606
# weighted avg       0.65      0.65      0.65     65606
#
# Accuracy:  0.6520897478889126
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65      8162
#          1.0       0.65      0.66      0.66      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.6533959273259359
# [[0.3479102521110874, 0.3466040726740641],
#  MLPClassifier(activation='logistic', random_state=0)]

# %%
# Using
# https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html
x = []
fa = []
fb = []
for i in range(200,4000,200):
    Error = executeNeuralNetwork(X, Y, iterations = i)
    x.append(i)
    fa.append(Error[0][0] * 100)
    fb.append(Error[0][1] * 100)
    
plotGraph(x, fa, x, fb, "Group Project", xvalrange = 4000, xAxisTitle = "Number of Iterations", title = "Number of Iterations")
# Out:
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 400, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 600, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 800, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 1000, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 1200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 1400, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 1600, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 1800, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 2000, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 2200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 2400, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 2600, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 2800, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 3000, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 3200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 3400, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 3600, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498
#
#
# Parameters:
# {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 3800, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69     32768
#          1.0       0.85      0.18      0.29     32838
#
#     accuracy                           0.57     65606
#    macro avg       0.70      0.57      0.49     65606
# weighted avg       0.70      0.57      0.49     65606
#
# Accuracy:  0.572279974392586
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.54      0.97      0.69      8162
#          1.0       0.86      0.18      0.29      8240
#
#     accuracy                           0.57     16402
#    macro avg       0.70      0.57      0.49     16402
# weighted avg       0.70      0.57      0.49     16402
#
# Accuracy:  0.5713937324716498

# %%
# Using
# https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html
x = []
fa = []
fb = []
for i in range(1,5):
    Error = executeNeuralNetwork(X, Y, layers = tuple([100 for item in range(1,i)]), act = 'logistic')
    x.append(i)
    fa.append(Error[0][0] * 100)
    fb.append(Error[0][1] * 100)
    
plotGraph(x, fa, x, fb, "Group Project", xvalrange = 4, xAxisTitle = "Number of Layers", title = "Number of Layers")
# Out:
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        48
#          1.0       0.52      1.00      0.68        52
#
#     accuracy                           0.52       100
#    macro avg       0.26      0.50      0.34       100
# weighted avg       0.27      0.52      0.36       100
#
# Accuracy:  0.52
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        12
#          1.0       0.54      1.00      0.70        14
#
#     accuracy                           0.54        26
#    macro avg       0.27      0.50      0.35        26
# weighted avg       0.29      0.54      0.38        26
#
# Accuracy:  0.5384615384615384
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.80      0.08      0.15        48
#          1.0       0.54      0.98      0.69        52
#
#     accuracy                           0.55       100
#    macro avg       0.67      0.53      0.42       100
# weighted avg       0.66      0.55      0.43       100
#
# Accuracy:  0.55
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.08      0.15        12
#          1.0       0.56      1.00      0.72        14
#
#     accuracy                           0.58        26
#    macro avg       0.78      0.54      0.44        26
# weighted avg       0.76      0.58      0.46        26
#
# Accuracy:  0.5769230769230769
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.60      0.25      0.35        48
#          1.0       0.55      0.85      0.67        52
#
#     accuracy                           0.56       100
#    macro avg       0.57      0.55      0.51       100
# weighted avg       0.57      0.56      0.52       100
#
# Accuracy:  0.56
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.50      0.33      0.40        12
#          1.0       0.56      0.71      0.63        14
#
#     accuracy                           0.54        26
#    macro avg       0.53      0.52      0.51        26
# weighted avg       0.53      0.54      0.52        26
#
# Accuracy:  0.5384615384615384
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (100, 100, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.35      0.45        48
#          1.0       0.58      0.81      0.67        52
#
#     accuracy                           0.59       100
#    macro avg       0.60      0.58      0.56       100
# weighted avg       0.60      0.59      0.57       100
#
# Accuracy:  0.59
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.50      0.42      0.45        12
#          1.0       0.56      0.64      0.60        14
#
#     accuracy                           0.54        26
#    macro avg       0.53      0.53      0.53        26
# weighted avg       0.53      0.54      0.53        26
#
# Accuracy:  0.5384615384615384

# %%
# Using
# https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html
x = []
fa = []
fb = []
for i in range(1,202,10):
    Error = executeNeuralNetwork(X, Y, layers = tuple([i]*2), act = 'logistic')
    x.append(i)
    fa.append(Error[0][0] * 100)
    fb.append(Error[0][1] * 100)
    
plotGraph(x, fa, x, fb, "Group Project", xvalrange = 200, xAxisTitle = "Size of Hidden Layer", title = "Size of Hidden Layer")
# Out:
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (1, 1), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     32768
#          1.0       0.50      1.00      0.67     32838
#
#     accuracy                           0.50     65606
#    macro avg       0.25      0.50      0.33     65606
# weighted avg       0.25      0.50      0.33     65606
#
# Accuracy:  0.5005334877907508
#
#
#
# -----------------------------------Report------------------------------------
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      8162
#          1.0       0.50      1.00      0.67      8240
#
#     accuracy                           0.50     16402
#    macro avg       0.25      0.50      0.33     16402
# weighted avg       0.25      0.50      0.34     16402
#
# Accuracy:  0.5023777588099012
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (11, 11), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.68      0.62      0.65     32768
#          1.0       0.65      0.71      0.68     32838
#
#     accuracy                           0.67     65606
#    macro avg       0.67      0.67      0.67     65606
# weighted avg       0.67      0.67      0.67     65606
#
# Accuracy:  0.6658232478736701
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.67      0.62      0.64      8162
#          1.0       0.65      0.70      0.68      8240
#
#     accuracy                           0.66     16402
#    macro avg       0.66      0.66      0.66     16402
# weighted avg       0.66      0.66      0.66     16402
#
# Accuracy:  0.6597975856602853
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (21, 21), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.68      0.61      0.65     32768
#          1.0       0.65      0.72      0.68     32838
#
#     accuracy                           0.66     65606
#    macro avg       0.67      0.66      0.66     65606
# weighted avg       0.67      0.66      0.66     65606
#
# Accuracy:  0.6641160869432674
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.68      0.60      0.64      8162
#          1.0       0.65      0.71      0.68      8240
#
#     accuracy                           0.66     16402
#    macro avg       0.66      0.66      0.66     16402
# weighted avg       0.66      0.66      0.66     16402
#
# Accuracy:  0.659126935739544
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (31, 31), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.67      0.66     32768
#          1.0       0.66      0.65      0.65     32838
#
#     accuracy                           0.66     65606
#    macro avg       0.66      0.66      0.66     65606
# weighted avg       0.66      0.66      0.66     65606
#
# Accuracy:  0.6583391762948511
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.67      0.66      8162
#          1.0       0.66      0.64      0.65      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.651688818436776
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (41, 41), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.66      0.66      0.66     32768
#          1.0       0.66      0.65      0.66     32838
#
#     accuracy                           0.66     65606
#    macro avg       0.66      0.66      0.66     65606
# weighted avg       0.66      0.66      0.66     65606
#
# Accuracy:  0.6572569582050423
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.66      0.65      8162
#          1.0       0.66      0.65      0.65      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.6531520546274845
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (51, 51), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.67      0.64      0.65     32768
#          1.0       0.66      0.68      0.67     32838
#
#     accuracy                           0.66     65606
#    macro avg       0.66      0.66      0.66     65606
# weighted avg       0.66      0.66      0.66     65606
#
# Accuracy:  0.6619364082553425
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.66      0.63      0.65      8162
#          1.0       0.65      0.68      0.66      8240
#
#     accuracy                           0.66     16402
#    macro avg       0.66      0.66      0.66     16402
# weighted avg       0.66      0.66      0.66     16402
#
# Accuracy:  0.6562004633581271
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (61, 61), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# c:\users\amaan\appdata\local\programs\python\python38\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.74      0.44      0.55     32768
#          1.0       0.60      0.84      0.70     32838
#
#     accuracy                           0.64     65606
#    macro avg       0.67      0.64      0.63     65606
# weighted avg       0.67      0.64      0.63     65606
#
# Accuracy:  0.6438587934030424
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.74      0.44      0.55      8162
#          1.0       0.60      0.85      0.71      8240
#
#     accuracy                           0.64     16402
#    macro avg       0.67      0.64      0.63     16402
# weighted avg       0.67      0.64      0.63     16402
#
# Accuracy:  0.6448603828801366
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (71, 71), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.68      0.66     32768
#          1.0       0.66      0.62      0.64     32838
#
#     accuracy                           0.65     65606
#    macro avg       0.65      0.65      0.65     65606
# weighted avg       0.65      0.65      0.65     65606
#
# Accuracy:  0.6543456391183733
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.64      0.68      0.66      8162
#          1.0       0.66      0.63      0.64      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.6532130228020973
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (81, 81), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.66      0.62      0.64     32768
#          1.0       0.64      0.68      0.66     32838
#
#     accuracy                           0.65     65606
#    macro avg       0.65      0.65      0.65     65606
# weighted avg       0.65      0.65      0.65     65606
#
# Accuracy:  0.6531262384537999
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.66      0.61      0.64      8162
#          1.0       0.64      0.69      0.66      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.6495549323253261
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (91, 91), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.67      0.62      0.64     32768
#          1.0       0.64      0.69      0.67     32838
#
#     accuracy                           0.65     65606
#    macro avg       0.66      0.65      0.65     65606
# weighted avg       0.66      0.65      0.65     65606
#
# Accuracy:  0.6546962168094381
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.66      0.61      0.64      8162
#          1.0       0.64      0.70      0.67      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.6523594683575173
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (101, 101), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.64      0.71      0.67     32768
#          1.0       0.67      0.60      0.63     32838
#
#     accuracy                           0.65     65606
#    macro avg       0.65      0.65      0.65     65606
# weighted avg       0.65      0.65      0.65     65606
#
# Accuracy:  0.6525470231381276
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.70      0.67      8162
#          1.0       0.67      0.60      0.63      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.6498597731983904
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (111, 111), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.69      0.67     32768
#          1.0       0.67      0.62      0.64     32838
#
#     accuracy                           0.66     65606
#    macro avg       0.66      0.66      0.66     65606
# weighted avg       0.66      0.66      0.66     65606
#
# Accuracy:  0.6559765875072402
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.64      0.68      0.66      8162
#          1.0       0.66      0.62      0.64      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.6506523594683575
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (121, 121), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.68      0.56      0.61     32768
#          1.0       0.63      0.74      0.68     32838
#
#     accuracy                           0.65     65606
#    macro avg       0.65      0.65      0.65     65606
# weighted avg       0.65      0.65      0.65     65606
#
# Accuracy:  0.6495442490016157
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.68      0.55      0.61      8162
#          1.0       0.62      0.75      0.68      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.64     16402
# weighted avg       0.65      0.65      0.64     16402
#
# Accuracy:  0.6472991098646507
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (131, 131), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.67      0.63      0.65     32768
#          1.0       0.65      0.68      0.67     32838
#
#     accuracy                           0.66     65606
#    macro avg       0.66      0.66      0.66     65606
# weighted avg       0.66      0.66      0.66     65606
#
# Accuracy:  0.6573636557631924
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.66      0.62      0.64      8162
#          1.0       0.65      0.68      0.66      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.6529691501036459
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (141, 141), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.68      0.61      0.64     32768
#          1.0       0.65      0.72      0.68     32838
#
#     accuracy                           0.66     65606
#    macro avg       0.67      0.66      0.66     65606
# weighted avg       0.67      0.66      0.66     65606
#
# Accuracy:  0.6641618144681889
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.68      0.60      0.64      8162
#          1.0       0.65      0.72      0.68      8240
#
#     accuracy                           0.66     16402
#    macro avg       0.66      0.66      0.66     16402
# weighted avg       0.66      0.66      0.66     16402
#
# Accuracy:  0.6593098402633825
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (151, 151), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.66      0.65      0.66     32768
#          1.0       0.66      0.66      0.66     32838
#
#     accuracy                           0.66     65606
#    macro avg       0.66      0.66      0.66     65606
# weighted avg       0.66      0.66      0.66     65606
#
# Accuracy:  0.6560375575404689
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.64      0.65      8162
#          1.0       0.65      0.66      0.66      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.6524814047067431
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (161, 161), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.69      0.67     32768
#          1.0       0.67      0.63      0.65     32838
#
#     accuracy                           0.66     65606
#    macro avg       0.66      0.66      0.66     65606
# weighted avg       0.66      0.66      0.66     65606
#
# Accuracy:  0.6586745114776088
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.64      0.69      0.66      8162
#          1.0       0.67      0.62      0.64      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.6537007681990001
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (171, 171), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.79      0.70     32768
#          1.0       0.72      0.52      0.60     32838
#
#     accuracy                           0.66     65606
#    macro avg       0.67      0.66      0.65     65606
# weighted avg       0.67      0.66      0.65     65606
#
# Accuracy:  0.6557022223577111
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.61      0.79      0.69      8162
#          1.0       0.71      0.51      0.59      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.66      0.65      0.64     16402
# weighted avg       0.66      0.65      0.64     16402
#
# Accuracy:  0.6487623460553591
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (181, 181), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.75      0.68     32768
#          1.0       0.69      0.55      0.61     32838
#
#     accuracy                           0.65     65606
#    macro avg       0.66      0.65      0.65     65606
# weighted avg       0.66      0.65      0.65     65606
#
# Accuracy:  0.6510532573240252
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.62      0.75      0.68      8162
#          1.0       0.69      0.54      0.60      8240
#
#     accuracy                           0.64     16402
#    macro avg       0.65      0.64      0.64     16402
# weighted avg       0.65      0.64      0.64     16402
#
# Accuracy:  0.6442507011340081
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (191, 191), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.66      0.66      0.66     32768
#          1.0       0.66      0.65      0.66     32838
#
#     accuracy                           0.66     65606
#    macro avg       0.66      0.66      0.66     65606
# weighted avg       0.66      0.66      0.66     65606
#
# Accuracy:  0.6576075358961071
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65      8162
#          1.0       0.65      0.65      0.65      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.6515668820875503
#
#
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (201, 201), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.67      0.61      0.64     32768
#          1.0       0.64      0.70      0.67     32838
#
#     accuracy                           0.65     65606
#    macro avg       0.66      0.65      0.65     65606
# weighted avg       0.66      0.65      0.65     65606
#
# Accuracy:  0.6540712739688443
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.67      0.60      0.63      8162
#          1.0       0.64      0.70      0.67      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.651688818436776

# %%
executeNeuralNetwork(X, Y, layers = tuple([10]*2), solverType= 'sgd', act = 'logistic', earlyStopping = True)
# Out:
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'sgd', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.66      0.65     32768
#          1.0       0.66      0.64      0.65     32838
#
#     accuracy                           0.65     65606
#    macro avg       0.65      0.65      0.65     65606
# weighted avg       0.65      0.65      0.65     65606
#
# Accuracy:  0.6508855897326464
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.66      0.65      8162
#          1.0       0.66      0.64      0.65      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.6508962321668089
# [[0.34911441026735357, 0.3491037678331911],
#  MLPClassifier(activation='logistic', early_stopping=True,
#                hidden_layer_sizes=(10, 10), random_state=0, solver='sgd')]

# %%
executeNeuralNetwork(X, Y, layers = tuple([10]*2), learningRate = 'invscaling', act = 'logistic', earlyStopping = True)
# Out:
# Parameters:
# {'activation': 'logistic', 'alpha': 0.0001, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': True, 'epsilon': 1e-08, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'learning_rate_init': 0.001, 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 0, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.64      0.68      0.66     32768
#          1.0       0.66      0.62      0.64     32838
#
#     accuracy                           0.65     65606
#    macro avg       0.65      0.65      0.65     65606
# weighted avg       0.65      0.65      0.65     65606
#
# Accuracy:  0.6508855897326464
#
#
#
# -----------------------------------Report------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.66      8162
#          1.0       0.66      0.63      0.64      8240
#
#     accuracy                           0.65     16402
#    macro avg       0.65      0.65      0.65     16402
# weighted avg       0.65      0.65      0.65     16402
#
# Accuracy:  0.6487013778807462
# [[0.34911441026735357, 0.3512986221192538],
#  MLPClassifier(activation='logistic', early_stopping=True,
#                hidden_layer_sizes=(10, 10), learning_rate='invscaling',
#                random_state=0)]
